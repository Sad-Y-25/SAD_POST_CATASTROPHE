# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras import layers, models, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split

# %% [markdown]
# Configuration des chemins

# %%
# Paths configuration
PROCESSED_PATH = '../dattest/processedtest/'
MODELS_PATH = '../models/'

# Create models folder if it does not exist
os.makedirs(MODELS_PATH, exist_ok=True)

print("Processed path :", PROCESSED_PATH)
print("Models path    :", MODELS_PATH)
# Out:
# Processed path : ../dattest/processedtest/
# Models path    : ../models/

# %% [markdown]
# Chargement des données

# %%
# Load image patches and road masks
X = np.load(os.path.join(PROCESSED_PATH, 'X_all.npy'))
Y = np.load(os.path.join(PROCESSED_PATH, 'Y_roads_all.npy'))

print("Données chargées avec succès.")
print("Shape X :", X.shape)
print("Shape Y :", Y.shape)
# Out:
# Données chargées avec succès.
# Shape X : (157, 256, 256, 3)
# Shape Y : (157, 256, 256, 1)

# %% [markdown]
# Vérification rapide des données

# %%
print("===== VÉRIFICATION DES DONNÉES =====")
print("Type X :", X.dtype)
print("Type Y :", Y.dtype)

print("Min X :", X.min())
print("Max X :", X.max())

print("Min Y :", Y.min())
print("Max Y :", Y.max())
# Out:
# ===== VÉRIFICATION DES DONNÉES =====
# Type X : float32
# Type Y : uint8
# Min X : 0.0
# Max X : 1.0
# Min Y : 0
# Max Y : 1

# %% [markdown]
# Statistique rapide sur les routes

# %%
road_pixels = np.sum(Y)
total_pixels = Y.size
road_ratio = road_pixels / total_pixels

print("===== STATISTIQUE ROUTES =====")
print("Pixels routes total :", road_pixels)
print("Pixels total        :", total_pixels)
print("Ratio global routes :", road_ratio)
# Out:
# ===== STATISTIQUE ROUTES =====
# Pixels routes total : 42092
# Pixels total        : 10289152
# Ratio global routes : 0.004090910504578026

# %% [markdown]
# Split train / validation / test

# %%
# First split: train and temporary set
X_train, X_temp, Y_train, Y_temp = train_test_split(
    X, Y,
    test_size=0.30,
    random_state=42,
    shuffle=True
)

# Second split: validation and test
X_val, X_test, Y_val, Y_test = train_test_split(
    X_temp, Y_temp,
    test_size=0.50,
    random_state=42,
    shuffle=True
)

print("===== SHAPES APRÈS SPLIT =====")
print("X_train :", X_train.shape)
print("Y_train :", Y_train.shape)

print("X_val   :", X_val.shape)
print("Y_val   :", Y_val.shape)

print("X_test  :", X_test.shape)
print("Y_test  :", Y_test.shape)
# Out:
# ===== SHAPES APRÈS SPLIT =====
# X_train : (109, 256, 256, 3)
# Y_train : (109, 256, 256, 1)
# X_val   : (24, 256, 256, 3)
# Y_val   : (24, 256, 256, 1)
# X_test  : (24, 256, 256, 3)
# Y_test  : (24, 256, 256, 1)

# %% [markdown]
# Dice coefficient et Dice loss

# %%
def dice_coef(y_true, y_pred):
    """
    Dice coefficient:
    measures the overlap between ground truth and prediction.
    Higher is better.
    """
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1])
    y_pred_f = tf.reshape(tf.cast(y_pred, tf.float32), [-1])

    intersection = tf.reduce_sum(y_true_f * y_pred_f)

    return (2. * intersection + 1.) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + 1.
    )


def dice_loss(y_true, y_pred):
    """
    Dice loss = 1 - Dice coefficient
    Lower is better.
    """
    return 1.0 - dice_coef(y_true, y_pred)

# %% [markdown]
# Métrique IoU

# %%
def iou_metric(y_true, y_pred):
    """
    Intersection over Union metric.
    """
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1])
    y_pred_f = tf.reshape(tf.cast(y_pred > 0.5, tf.float32), [-1])

    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection

    return (intersection + 1.) / (union + 1.)

# %% [markdown]
# Construction du modèle U-Net

# %%
def unet_model(input_size=(256, 256, 3)):
    inputs = Input(input_size)

    # ===== Encoder =====
    c1 = layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
    c1 = layers.Dropout(0.1)(c1)
    c1 = layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = layers.Dropout(0.1)(c2)
    c2 = layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = layers.Dropout(0.2)(c3)
    c3 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    # ===== Bottleneck =====
    c4 = layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = layers.Dropout(0.3)(c4)
    c4 = layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)

    # ===== Decoder =====
    u5 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c4)
    u5 = layers.concatenate([u5, c3])
    c5 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u5)
    c5 = layers.Dropout(0.2)(c5)
    c5 = layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

    u6 = layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c2])
    c6 = layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = layers.Dropout(0.1)(c6)
    c6 = layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

    u7 = layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c1])
    c7 = layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = layers.Dropout(0.1)(c7)
    c7 = layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

    # ===== Output =====
    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(c7)

    model = models.Model(inputs=[inputs], outputs=[outputs])
    return model

# %% [markdown]
# Compilation du modèle

# %%
model = unet_model()

model.compile(
    optimizer='adam',
    loss=dice_loss,
    metrics=[dice_coef, iou_metric]
)

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256, 256,  │          0 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      2,320 │ dropout[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │      9,248 │ dropout_1[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │     36,928 │ dropout_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    147,584 │ dropout_3[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 64, 64,    │     32,832 │ conv2d_7[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │     73,792 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_8[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │     36,928 │ dropout_4[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 128, 128,  │      8,224 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 128, 128,  │     18,464 │ concatenate_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_10[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 128,  │      9,248 │ dropout_5[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 256, 256,  │      2,064 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 256, 256,  │      4,624 │ concatenate_2[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 256, 256,  │          0 │ conv2d_12[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 256, 256,  │      2,320 │ dropout_6[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 256, 256,  │         17 │ conv2d_13[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 482,033 (1.84 MB)
#  Trainable params: 482,033 (1.84 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Callbacks

# %%
# Best model path
best_model_path = os.path.join(MODELS_PATH, 'unet_roads_best.keras')

callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=best_model_path,
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
]

print("Callbacks configurés.")
print("Best model path :", best_model_path)
# Out:
# Callbacks configurés.
# Best model path : ../models/unet_roads_best.keras

# %% [markdown]
# Entraînement

# %%
print("Début de l'entraînement du modèle routes...")

history = model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    epochs=50,
    batch_size=8,
    shuffle=True,
    callbacks=callbacks,
    verbose=1
)

print("Entraînement terminé.")
# Out:
# Début de l'entraînement du modèle routes...
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - dice_coef: 0.0078 - iou_metric: 0.0036 - loss: 0.9922
# Epoch 1: val_loss improved from None to 0.98985, saving model to ../models/unet_roads_best.keras
#
# Epoch 1: finished saving model to ../models/unet_roads_best.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 12s 584ms/step - dice_coef: 0.0085 - iou_metric: 0.0040 - loss: 0.9915 - val_dice_coef: 0.0102 - val_iou_metric: 0.0047 - val_loss: 0.9898
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - dice_coef: 0.0097 - iou_metric: 0.0048 - loss: 0.9903
# Epoch 2: val_loss improved from 0.98985 to 0.98245, saving model to ../models/unet_roads_best.keras
#
# Epoch 2: finished saving model to ../models/unet_roads_best.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 537ms/step - dice_coef: 0.0100 - iou_metric: 0.0054 - loss: 0.9900 - val_dice_coef: 0.0175 - val_iou_metric: 0.0093 - val_loss: 0.9825
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - dice_coef: 0.0169 - iou_metric: 0.0090 - loss: 0.9831
# Epoch 3: val_loss did not improve from 0.98245
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 515ms/step - dice_coef: 0.0153 - iou_metric: 0.0081 - loss: 0.9847 - val_dice_coef: 0.0142 - val_iou_metric: 0.0073 - val_loss: 0.9858
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - dice_coef: 0.0226 - iou_metric: 0.0118 - loss: 0.9774
# Epoch 4: val_loss improved from 0.98245 to 0.95708, saving model to ../models/unet_roads_best.keras
#
# Epoch 4: finished saving model to ../models/unet_roads_best.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 519ms/step - dice_coef: 0.0301 - iou_metric: 0.0157 - loss: 0.9699 - val_dice_coef: 0.0429 - val_iou_metric: 0.0224 - val_loss: 0.9571
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - dice_coef: 0.0406 - iou_metric: 0.0211 - loss: 0.9594
# Epoch 5: val_loss improved from 0.95708 to 0.95598, saving model to ../models/unet_roads_best.keras
#
# Epoch 5: finished saving model to ../models/unet_roads_best.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 539ms/step - dice_coef: 0.0455 - iou_metric: 0.0237 - loss: 0.9541 - val_dice_coef: 0.0440 - val_iou_metric: 0.0226 - val_loss: 0.9560
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - dice_coef: 0.0476 - iou_metric: 0.0246 - loss: 0.9524
# Epoch 6: val_loss did not improve from 0.95598
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 537ms/step - dice_coef: 0.0400 - iou_metric: 0.0206 - loss: 0.9596 - val_dice_coef: 0.0277 - val_iou_metric: 0.0141 - val_loss: 0.9723
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 676ms/step - dice_coef: 0.0237 - iou_metric: 0.0120 - loss: 0.9763
# Epoch 7: val_loss did not improve from 0.95598
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 726ms/step - dice_coef: 0.0273 - iou_metric: 0.0139 - loss: 0.9724 - val_dice_coef: 0.0308 - val_iou_metric: 0.0158 - val_loss: 0.9692
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - dice_coef: 0.0222 - iou_metric: 0.0113 - loss: 0.9778
# Epoch 8: val_loss did not improve from 0.95598
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 635ms/step - dice_coef: 0.0260 - iou_metric: 0.0132 - loss: 0.9745 - val_dice_coef: 0.0406 - val_iou_metric: 0.0207 - val_loss: 0.9594
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 587ms/step - dice_coef: 0.0319 - iou_metric: 0.0164 - loss: 0.9681
# Epoch 9: val_loss improved from 0.95598 to 0.94255, saving model to ../models/unet_roads_best.keras
#
# Epoch 9: finished saving model to ../models/unet_roads_best.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 645ms/step - dice_coef: 0.0348 - iou_metric: 0.0178 - loss: 0.9650 - val_dice_coef: 0.0574 - val_iou_metric: 0.0297 - val_loss: 0.9426
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - dice_coef: 0.0449 - iou_metric: 0.0231 - loss: 0.9551
# Epoch 10: val_loss did not improve from 0.94255
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 611ms/step - dice_coef: 0.0454 - iou_metric: 0.0234 - loss: 0.9541 - val_dice_coef: 0.0565 - val_iou_metric: 0.0292 - val_loss: 0.9435
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - dice_coef: 0.0584 - iou_metric: 0.0302 - loss: 0.9415
# Epoch 11: val_loss did not improve from 0.94255
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 589ms/step - dice_coef: 0.0500 - iou_metric: 0.0259 - loss: 0.9490 - val_dice_coef: 0.0337 - val_iou_metric: 0.0172 - val_loss: 0.9663
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - dice_coef: 0.0329 - iou_metric: 0.0168 - loss: 0.9671
# Epoch 12: val_loss did not improve from 0.94255
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 618ms/step - dice_coef: 0.0346 - iou_metric: 0.0177 - loss: 0.9646 - val_dice_coef: 0.0154 - val_iou_metric: 0.0081 - val_loss: 0.9846
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - dice_coef: 0.0014 - iou_metric: 9.3962e-04 - loss: 0.9986
# Epoch 13: val_loss did not improve from 0.94255
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 569ms/step - dice_coef: 8.1580e-04 - iou_metric: 6.6953e-04 - loss: 0.9992 - val_dice_coef: 4.1158e-04 - val_iou_metric: 4.1158e-04 - val_loss: 0.9996
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - dice_coef: 4.8482e-04 - iou_metric: 4.8483e-04 - loss: 0.9995
# Epoch 14: val_loss did not improve from 0.94255
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 563ms/step - dice_coef: 5.1294e-04 - iou_metric: 5.1294e-04 - loss: 0.9995 - val_dice_coef: 4.1158e-04 - val_iou_metric: 4.1158e-04 - val_loss: 0.9996
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - dice_coef: 5.3282e-04 - iou_metric: 5.3283e-04 - loss: 0.9995
# Epoch 15: val_loss did not improve from 0.94255
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 577ms/step - dice_coef: 4.9734e-04 - iou_metric: 4.9734e-04 - loss: 0.9995 - val_dice_coef: 4.1158e-04 - val_iou_metric: 4.1158e-04 - val_loss: 0.9996
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - dice_coef: 4.5711e-04 - iou_metric: 4.5711e-04 - loss: 0.9995
# Epoch 16: val_loss did not improve from 0.94255
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 709ms/step - dice_coef: 5.0455e-04 - iou_metric: 5.0455e-04 - loss: 0.9995 - val_dice_coef: 4.1158e-04 - val_iou_metric: 4.1158e-04 - val_loss: 0.9996
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 725ms/step - dice_coef: 5.0580e-04 - iou_metric: 5.0580e-04 - loss: 0.9995
# Epoch 17: val_loss did not improve from 0.94255
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 786ms/step - dice_coef: 5.0888e-04 - iou_metric: 5.0888e-04 - loss: 0.9995 - val_dice_coef: 4.1158e-04 - val_iou_metric: 4.1158e-04 - val_loss: 0.9996
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 659ms/step - dice_coef: 4.9739e-04 - iou_metric: 4.9739e-04 - loss: 0.9995
# Epoch 18: val_loss did not improve from 0.94255
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 710ms/step - dice_coef: 5.0881e-04 - iou_metric: 5.0881e-04 - loss: 0.9995 - val_dice_coef: 4.1158e-04 - val_iou_metric: 4.1158e-04 - val_loss: 0.9996
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 627ms/step - dice_coef: 4.8104e-04 - iou_metric: 4.8105e-04 - loss: 0.9995
# Epoch 19: val_loss did not improve from 0.94255
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 710ms/step - dice_coef: 5.2544e-04 - iou_metric: 5.2544e-04 - loss: 0.9995 - val_dice_coef: 4.1158e-04 - val_iou_metric: 4.1158e-04 - val_loss: 0.9996
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Entraînement terminé.

# %% [markdown]
# Courbes d’apprentissage

# %%
# Plot training and validation loss
plt.figure(figsize=(8, 4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Courbe de loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# Plot Dice coefficient
plt.figure(figsize=(8, 4))
plt.plot(history.history['dice_coef'], label='Train Dice')
plt.plot(history.history['val_dice_coef'], label='Validation Dice')
plt.title("Courbe Dice Coefficient")
plt.xlabel("Epoch")
plt.ylabel("Dice")
plt.legend()
plt.show()

# Plot IoU
plt.figure(figsize=(8, 4))
plt.plot(history.history['iou_metric'], label='Train IoU')
plt.plot(history.history['val_iou_metric'], label='Validation IoU')
plt.title("Courbe IoU")
plt.xlabel("Epoch")
plt.ylabel("IoU")
plt.legend()
plt.show()

# %% [markdown]
# Évaluation sur le jeu de test

# %%
print("Évaluation sur le jeu de test...")

test_results = model.evaluate(X_test, Y_test, verbose=1)

print("\n===== RÉSULTATS TEST =====")
print("Test Loss       :", test_results[0])
print("Test Dice       :", test_results[1])
print("Test IoU        :", test_results[2])
# Out:
# Évaluation sur le jeu de test...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - dice_coef: 0.0380 - iou_metric: 0.0194 - loss: 0.9620
#
# ===== RÉSULTATS TEST =====
# Test Loss       : 0.9619634747505188
# Test Dice       : 0.038036465644836426
# Test IoU        : 0.019351167604327202

# %% [markdown]
# Chargement du meilleur modèle

# %%
best_model = tf.keras.models.load_model(
    best_model_path,
    custom_objects={
        'dice_loss': dice_loss,
        'dice_coef': dice_coef,
        'iou_metric': iou_metric
    }
)

print("Meilleur modèle chargé avec succès.")
# Out:
# Meilleur modèle chargé avec succès.

# %% [markdown]
# Prédiction sur quelques exemples du test

# %%
num_examples = min(5, len(X_test))
indices = np.random.choice(len(X_test), size=num_examples, replace=False)

preds = best_model.predict(X_test[indices])
preds_bin = (preds > 0.5).astype(np.uint8)

plt.figure(figsize=(15, 5 * num_examples))

for k, idx in enumerate(range(num_examples)):
    plt.subplot(num_examples, 3, 3*k + 1)
    plt.imshow(X_test[indices][idx])
    plt.title("Image test")
    plt.axis('off')

    plt.subplot(num_examples, 3, 3*k + 2)
    plt.imshow(Y_test[indices][idx].squeeze(), cmap='gray')
    plt.title("Vrai masque routes")
    plt.axis('off')

    plt.subplot(num_examples, 3, 3*k + 3)
    plt.imshow(preds_bin[idx].squeeze(), cmap='gray')
    plt.title("Prédiction routes")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step

# %% [markdown]
# Affichage des probabilités brutes

# %%
num_examples = min(3, len(X_test))
indices = np.random.choice(len(X_test), size=num_examples, replace=False)

preds = best_model.predict(X_test[indices])

plt.figure(figsize=(15, 5 * num_examples))

for k, idx in enumerate(range(num_examples)):
    plt.subplot(num_examples, 3, 3*k + 1)
    plt.imshow(X_test[indices][idx])
    plt.title("Image test")
    plt.axis('off')

    plt.subplot(num_examples, 3, 3*k + 2)
    plt.imshow(Y_test[indices][idx].squeeze(), cmap='gray')
    plt.title("Vrai masque")
    plt.axis('off')

    plt.subplot(num_examples, 3, 3*k + 3)
    plt.imshow(preds[idx].squeeze(), cmap='gray')
    plt.title("Probabilités prédites")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step

# %% [markdown]
# Test de seuils différents

# %%
# Test different thresholds for road segmentation
thresholds = [0.5, 0.3, 0.1]

sample_idx = np.random.randint(0, len(X_test))
sample_img = X_test[sample_idx:sample_idx+1]
sample_true = Y_test[sample_idx].squeeze()
sample_pred = best_model.predict(sample_img)[0].squeeze()

plt.figure(figsize=(15, 4))

plt.subplot(1, 5, 1)
plt.imshow(sample_img[0])
plt.title("Image")
plt.axis('off')

plt.subplot(1, 5, 2)
plt.imshow(sample_true, cmap='gray')
plt.title("Vrai masque")
plt.axis('off')

plt.subplot(1, 5, 3)
plt.imshow((sample_pred > thresholds[0]).astype(np.uint8), cmap='gray')
plt.title(f"Seuil {thresholds[0]}")
plt.axis('off')

plt.subplot(1, 5, 4)
plt.imshow((sample_pred > thresholds[1]).astype(np.uint8), cmap='gray')
plt.title(f"Seuil {thresholds[1]}")
plt.axis('off')

plt.subplot(1, 5, 5)
plt.imshow((sample_pred > thresholds[2]).astype(np.uint8), cmap='gray')
plt.title(f"Seuil {thresholds[2]}")
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step

# %% [markdown]
# Sauvegarde finale du modèle

# %%
final_model_path = os.path.join(MODELS_PATH, 'unet_roads_final.keras')

model.save(final_model_path)

print("Modèle final sauvegardé avec succès.")
print("Chemin :", final_model_path)
# Out:
# Modèle final sauvegardé avec succès.
# Chemin : ../models/unet_roads_final.keras

# %% [markdown]
# Résumé final

# %%
print("===== RÉSUMÉ FINAL =====")
print("Dataset total          :", X.shape)
print("Train set              :", X_train.shape)
print("Validation set         :", X_val.shape)
print("Test set               :", X_test.shape)

print("\nModèles sauvegardés :")
print("- Best model  :", best_model_path)
print("- Final model :", final_model_path)
# Out:
# ===== RÉSUMÉ FINAL =====
# Dataset total          : (157, 256, 256, 3)
# Train set              : (109, 256, 256, 3)
# Validation set         : (24, 256, 256, 3)
# Test set               : (24, 256, 256, 3)
#
# Modèles sauvegardés :
# - Best model  : ../models/unet_roads_best.keras
# - Final model : ../models/unet_roads_final.keras
